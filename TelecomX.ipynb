# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniBntz/AluraStore/blob/main/TelecomX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extracción

# %%
import pandas as pd

# %%
dt = pd.read_json('/content/TelecomX_Data.json')

# %%
dt
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
#Primero Extraigola información anidada
customer = pd.json_normalize(dt['customer'])
phone = pd.json_normalize(dt['phone'])
internet = pd.json_normalize(dt['internet'])
account = pd.json_normalize(dt['account'])

# %%
#ahora voy a unir todo en un solo DF para poder verlo mejor.

datos = pd.concat([dt, customer, phone, internet, account], axis=1)

# %%
#compruebo
datos.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 1879  2669-QVCRG    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1189  1698-XFZCI    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2626  3658-QQJYD    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3212  4484-CGXFK   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6479  8903-XEBGX    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 1879  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 1189  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2626   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3212   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6479   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 1879  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 1189  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 2626  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 3212  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6479  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account  gender  \
# 1879  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 1189  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 2626  {'Contract': 'One year', 'PaperlessBilling': '...    Male
# 3212  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 6479  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
#
#       SeniorCitizen Partner Dependents  ...  OnlineBackup DeviceProtection  \
# 1879              0      No         No  ...            No               No
# 1189              0      No         No  ...           Yes              Yes
# 2626              0      No         No  ...           Yes               No
# 3212              0      No         No  ...            No               No
# 6479              0      No        Yes  ...            No               No
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1879          No          No              No  Month-to-month              Yes
# 1189          No         Yes             Yes        One year              Yes
# 2626          No         Yes             Yes        One year              Yes
# 3212          No          No             Yes  Month-to-month              Yes
# 6479          No          No             Yes  Month-to-month              Yes
#
#                 PaymentMethod Charges.Monthly Charges.Total
# 1879  Credit card (automatic)           81.30       3190.65
# 1189         Electronic check          107.75        6521.9
# 2626  Credit card (automatic)           74.30       4698.05
# 3212         Electronic check           55.30        196.15
# 6479         Electronic check           55.30        108.65
#
# [5 rows x 25 columns]

# %%
#Elimino las columnas que no me sirven.
datos.drop(['customer', 'phone', 'internet', 'account'], axis=1, inplace=True)

datos.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2888  4003-OCTMP    No  Female              0     Yes         No      31
# 2623  3656-TKRVZ   Yes  Female              0      No         No       3
# 5777  7893-IXHRQ   Yes    Male              0      No         No       1
# 6267  8625-AZYZY   Yes    Male              0     Yes         No      24
# 3741  5149-CUZUJ    No    Male              0     Yes        Yes      28
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 2888          Yes            No             DSL  ...                   No
# 2623          Yes            No             DSL  ...                  Yes
# 5777          Yes            No              No  ...  No internet service
# 6267          Yes           Yes     Fiber optic  ...                  Yes
# 3741          Yes            No     Fiber optic  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 2888                   No                  Yes                   No
# 2623                   No                   No                   No
# 5777  No internet service  No internet service  No internet service
# 6267                  Yes                   No                  Yes
# 3741                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 2888                  Yes        One year              Yes
# 2623                   No  Month-to-month               No
# 5777  No internet service  Month-to-month               No
# 6267                  Yes  Month-to-month              Yes
# 3741                   No        One year               No
#
#                   PaymentMethod Charges.Monthly  Charges.Total
# 2888           Electronic check           64.00        1910.75
# 2623           Electronic check           55.35          165.2
# 5777           Electronic check           20.55          20.55
# 6267           Electronic check          104.65        2542.45
# 3741  Bank transfer (automatic)           92.90        2768.35
#
# [5 rows x 21 columns]

# %% [markdown]
# #Transformación

# %%
#reviso la información de las columnas
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
#A primera vista noto que: Charges.Total, debe ser una columna tipo float.
#reviso la información que contiene la columna primero
datos['Charges.Total'].value_counts()
# Out:
# Charges.Total
# 20.2       11
#            11
# 19.75       9
# 19.55       9
# 19.9        9
#            ..
# 1993.2      1
# 72.1        1
# 1237.85     1
# 542.4       1
# 593.3       1
# Name: count, Length: 6531, dtype: int64

# %%
datos['Charges.Total'].unique()
# Out:
# array(['593.3', '542.4', '280.85', ..., '742.9', '4627.65', '3707.6'],
#       dtype=object)

# %%
import numpy as np

# %%
#Ahora elimino los caracteres que me pueden impedir transformar a float
datos['Charges.Total'] = datos['Charges.Total'].str.replace(',', '').replace('$', '').replace(' ', '').replace('', None)
#Tranformo a float
datos['Charges.Total'] = datos['Charges.Total'].astype(np.float64)
#reviso
datos['Charges.Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Charges.Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
datos['Charges.Total'].value_counts()
# Out:
# Charges.Total
# 20.20      11
# 19.75       9
# 19.90       9
# 19.55       9
# 20.05       8
#            ..
# 7261.25     1
# 6849.40     1
# 1993.20     1
# 72.10       1
# 7382.25     1
# Name: count, Length: 6530, dtype: int64

# %%
datos.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 918   1299-AURJA    No  Female              0     Yes        Yes      70
# 1383  2000-MPKCA    No  Female              0      No         No      58
# 517   0731-EBJQB    No  Female              0     Yes        Yes      52
# 971   1360-XFJMR    No  Female              0     Yes         No      67
# 2989  4140-TOILV          Male              0     Yes         No      22
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 918           Yes           Yes              No  ...  No internet service
# 1383          Yes           Yes     Fiber optic  ...                  Yes
# 517           Yes            No              No  ...  No internet service
# 971           Yes           Yes     Fiber optic  ...                  Yes
# 2989          Yes            No     Fiber optic  ...                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 918   No internet service  No internet service  No internet service
# 1383                  Yes                   No                  Yes
# 517   No internet service  No internet service  No internet service
# 971                   Yes                  Yes                  Yes
# 2989                  Yes                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 918   No internet service        Two year               No
# 1383                  Yes        One year              Yes
# 517   No internet service        One year              Yes
# 971                   Yes        One year              Yes
# 2989                   No  Month-to-month              Yes
#
#                   PaymentMethod Charges.Monthly  Charges.Total
# 918   Bank transfer (automatic)           24.70        1685.90
# 1383           Electronic check          107.75        6332.75
# 517            Electronic check           20.40        1090.65
# 971     Credit card (automatic)          109.70        7344.45
# 2989  Bank transfer (automatic)           87.00        1850.65
#
# [5 rows x 21 columns]

# %% [markdown]
# #Carga y Análisis

# %% [markdown]
# #Informe Final
