# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniBntz/AluraStore/blob/main/TelecomX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extracción

# %%
import pandas as pd

# %%
dt = pd.read_json('/content/TelecomX_Data.json')

# %%
dt
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...                                                 ...
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 0     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1     {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3     {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4     {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...                                                 ...
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                                 account
# 0     {'Contract': 'One year', 'PaperlessBilling': '...
# 1     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...                                                 ...
# 7262  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 6 columns]

# %%
#Primero Extraigola información anidada
customer = pd.json_normalize(dt['customer'])
phone = pd.json_normalize(dt['phone'])
internet = pd.json_normalize(dt['internet'])
account = pd.json_normalize(dt['account'])

# %%
#ahora voy a unir todo en un solo DF para poder verlo mejor.

datos = pd.concat([dt, customer, phone, internet, account], axis=1)

# %%
#compruebo
datos.sample(5)
# Out:
#       customerID Churn                                           customer  \
# 7002  9640-HXEAM        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4507  6175-IRFIT    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3755  5161-UBZXI    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3352  4659-NZRUF   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7064  9728-FTTVZ   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# 7002  {'PhoneService': 'No', 'MultipleLines': 'No ph...
# 4507     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3755     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3352    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7064     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                                internet  \
# 7002  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 4507  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3755  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3352  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7064  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                                 account  gender  \
# 7002  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 4507  {'Contract': 'Month-to-month', 'PaperlessBilli...    Male
# 3755  {'Contract': 'Two year', 'PaperlessBilling': '...    Male
# 3352  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
# 7064  {'Contract': 'Month-to-month', 'PaperlessBilli...  Female
#
#       SeniorCitizen Partner Dependents  ...  OnlineBackup DeviceProtection  \
# 7002              0      No         No  ...           Yes              Yes
# 4507              0      No         No  ...            No               No
# 3755              0     Yes        Yes  ...           Yes               No
# 3352              0      No         No  ...           Yes               No
# 7064              0      No         No  ...            No               No
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 7002         Yes          No              No  Month-to-month              Yes
# 4507          No          No             Yes  Month-to-month               No
# 3755         Yes         Yes             Yes        Two year              Yes
# 3352          No          No             Yes  Month-to-month              Yes
# 7064          No          No              No  Month-to-month              Yes
#
#                 PaymentMethod Charges.Monthly Charges.Total
# 7002  Credit card (automatic)           40.40         77.15
# 4507             Mailed check           78.75        426.35
# 3755  Credit card (automatic)          106.35       7261.75
# 3352         Electronic check           95.15       1789.25
# 7064         Electronic check           69.20          69.2
#
# [5 rows x 25 columns]

# %%
#Elimino las columnas que no me sirven.
datos.drop(['customer', 'phone', 'internet', 'account'], axis=1, inplace=True)

datos.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 694   0983-TATYJ    No  Female              0     Yes         No      33
# 6113  8361-LTMKD   Yes    Male              1     Yes         No       4
# 2411  3370-HXOPH    No  Female              0      No         No       3
# 6074  8294-UIMBA    No  Female              0      No         No      30
# 5135  7011-CVEUC    No    Male              0     Yes         No      25
#
#      PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 694           Yes            No             DSL  ...           No
# 6113          Yes           Yes     Fiber optic  ...           No
# 2411          Yes           Yes     Fiber optic  ...           No
# 6074          Yes            No     Fiber optic  ...           No
# 5135          Yes            No     Fiber optic  ...           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 694                No         Yes          No              No        One year
# 6113               No          No          No              No  Month-to-month
# 2411               No          No          No              No  Month-to-month
# 6074               No         Yes         Yes             Yes        One year
# 5135               No         Yes         Yes             Yes  Month-to-month
#
#      PaperlessBilling              PaymentMethod Charges.Monthly  \
# 694               Yes               Mailed check           51.45
# 6113              Yes               Mailed check           74.40
# 2411               No           Electronic check           76.10
# 6074              Yes  Bank transfer (automatic)           94.40
# 5135              Yes    Credit card (automatic)           95.70
#
#       Charges.Total
# 694          1758.9
# 6113          306.6
# 2411          257.6
# 6074         2638.1
# 5135        2338.35
#
# [5 rows x 21 columns]

# %% [markdown]
# #Transformación

# %%
#reviso la información de las columnas
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
#A primera vista noto que: Charges.Total, debe ser una columna tipo float.
#reviso la información que contiene la columna primero
datos['Charges.Total'].value_counts()
# Out:
# Charges.Total
# 20.2       11
#            11
# 19.75       9
# 19.55       9
# 19.9        9
#            ..
# 1993.2      1
# 72.1        1
# 1237.85     1
# 542.4       1
# 593.3       1
# Name: count, Length: 6531, dtype: int64

# %%
datos['Charges.Total'].unique()
# Out:
# array(['593.3', '542.4', '280.85', ..., '742.9', '4627.65', '3707.6'],
#       dtype=object)

# %%
import numpy as np

# %%
#Ahora elimino los caracteres que me pueden impedir transformar a float
datos['Charges.Total'] = datos['Charges.Total'].str.replace(',', '').replace('$', '').replace(' ', '').replace('', None)
#Tranformo a float
datos['Charges.Total'] = datos['Charges.Total'].astype(np.float64)
#reviso
datos['Charges.Total'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: Charges.Total
# Non-Null Count  Dtype
# --------------  -----
# 7256 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %%
datos['Charges.Total'].sample(10)
# Out:
# 2378     266.80
# 1773    6339.45
# 643     1346.30
# 4432    2535.55
# 399      653.90
# 4281    5563.65
# 3062    6000.10
# 3223    3255.35
# 6664      45.70
# 4212     592.65
# Name: Charges.Total, dtype: float64

# %%
datos.sample(5)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 3399  4710-FDUIZ   Yes    Male              0     Yes         No      56
# 636   0906-QVPMS    No    Male              0     Yes         No      72
# 1395  2017-CCBLH    No  Female              0      No         No       8
# 875   1231-YNDEK    No    Male              0      No         No      58
# 5898  8060-HIWJJ    No    Male              0      No         No      64
#
#      PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 3399          Yes           Yes     Fiber optic  ...                  Yes
# 636           Yes           Yes     Fiber optic  ...                  Yes
# 1395          Yes            No              No  ...  No internet service
# 875           Yes            No              No  ...  No internet service
# 5898          Yes           Yes             DSL  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 3399                   No                   No                  Yes
# 636                   Yes                  Yes                  Yes
# 1395  No internet service  No internet service  No internet service
# 875   No internet service  No internet service  No internet service
# 5898                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling  \
# 3399                  Yes  One year               No
# 636                   Yes  Two year               No
# 1395  No internet service  Two year               No
# 875   No internet service  Two year              Yes
# 5898                  Yes  Two year               No
#
#                   PaymentMethod Charges.Monthly  Charges.Total
# 3399    Credit card (automatic)          100.30        5614.45
# 636   Bank transfer (automatic)          115.15        8349.45
# 1395               Mailed check           20.00         141.60
# 875   Bank transfer (automatic)           19.15        1035.50
# 5898    Credit card (automatic)           86.55        5632.55
#
# [5 rows x 21 columns]

# %%
datos.nunique()
# Out:
# customerID          7267
# Churn                  3
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# Charges.Monthly     1585
# Charges.Total       6530
# dtype: int64

# %%
#como son muchos datos, revisaré columna por columna

for col in datos.columns:
    print(f"\n--- {col} ---")
    print(datos[col].value_counts())
# Out:
# --- customerID ---
# customerID
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7267, dtype: int64
#
# --- Churn ---
# Churn
# No     5174
# Yes    1869
#         224
# Name: count, dtype: int64
#
# --- gender ---
# gender
# Male      3675
# Female    3592
# Name: count, dtype: int64
#
# --- SeniorCitizen ---
# SeniorCitizen
# 0    6085
# 1    1182
# Name: count, dtype: int64
#
# --- Partner ---
# Partner
# No     3749
# Yes    3518
# Name: count, dtype: int64
#
# --- Dependents ---
# Dependents
# No     5086
# Yes    2181
# Name: count, dtype: int64
#
# --- tenure ---
# tenure
# 1     634
# 72    369
# 2     246
# 3     207
# 4     185
#      ...
# 28     60
# 39     59
# 44     54
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
#
# --- PhoneService ---
# PhoneService
# Yes    6560
# No      707
# Name: count, dtype: int64
#
# --- MultipleLines ---
# MultipleLines
# No                  3495
# Yes                 3065
# No phone service     707
# Name: count, dtype: int64
#
# --- InternetService ---
# InternetService
# Fiber optic    3198
# DSL            2488
# No             1581
# Name: count, dtype: int64
#
# --- OnlineSecurity ---
# OnlineSecurity
# No                     3608
# Yes                    2078
# No internet service    1581
# Name: count, dtype: int64
#
# --- OnlineBackup ---
# OnlineBackup
# No                     3182
# Yes                    2504
# No internet service    1581
# Name: count, dtype: int64
#
# --- DeviceProtection ---
# DeviceProtection
# No                     3195
# Yes                    2491
# No internet service    1581
# Name: count, dtype: int64
#
# --- TechSupport ---
# TechSupport
# No                     3582
# Yes                    2104
# No internet service    1581
# Name: count, dtype: int64
#
# --- StreamingTV ---
# StreamingTV
# No                     2896
# Yes                    2790
# No internet service    1581
# Name: count, dtype: int64
#
# --- StreamingMovies ---
# StreamingMovies
# No                     2870
# Yes                    2816
# No internet service    1581
# Name: count, dtype: int64
#
# --- Contract ---
# Contract
# Month-to-month    4005
# Two year          1743
# One year          1519
# Name: count, dtype: int64
#
# --- PaperlessBilling ---
# PaperlessBilling
# Yes    4311
# No     2956
# Name: count, dtype: int64
#
# --- PaymentMethod ---
# PaymentMethod
# Electronic check             2445
# Mailed check                 1665
# Bank transfer (automatic)    1589
# Credit card (automatic)      1568
# Name: count, dtype: int64
#
# --- Charges.Monthly ---
# Charges.Monthly
# 20.05    65
# 19.90    46
# 19.85    46
# 19.55    45
# 19.70    45
#          ..
# 87.90     1
# 87.60     1
# 52.20     1
# 68.30     1
# 66.60     1
# Name: count, Length: 1585, dtype: int64
#
# --- Charges.Total ---
# Charges.Total
# 20.20      11
# 19.75       9
# 19.90       9
# 19.55       9
# 20.05       8
#            ..
# 7261.25     1
# 6849.40     1
# 1993.20     1
# 72.10       1
# 7382.25     1
# Name: count, Length: 6530, dtype: int64

# %%
#identifico que hay columnas que son tip object y deberían ser booleanas
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7256 non-null   float64
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.2+ MB

# %%
#primero empiezo transformando la columna Senior citizen
datos['SeniorCitizen'] = datos['SeniorCitizen'].astype(bool)

datos['SeniorCitizen'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7267 entries, 0 to 7266
# Series name: SeniorCitizen
# Non-Null Count  Dtype
# --------------  -----
# 7267 non-null   bool
# dtypes: bool(1)
# memory usage: 7.2 KB

# %%
datos.sample(3)
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 2507  3503-TYDAY    No  Female          False     Yes         No      43
# 7266  9995-HOTOH    No    Male          False     Yes        Yes      63
# 1726  2453-SAFNS    No  Female           True      No         No      54
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 2507          Yes               Yes     Fiber optic  ...          Yes
# 7266           No  No phone service             DSL  ...          Yes
# 1726          Yes               Yes             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 2507               No          No          No              No  Month-to-month
# 7266              Yes          No         Yes             Yes        Two year
# 1726               No         Yes         Yes              No        One year
#
#      PaperlessBilling     PaymentMethod Charges.Monthly  Charges.Total
# 2507               No  Electronic check           80.45        3398.90
# 7266               No  Electronic check           59.00        3707.60
# 1726               No      Mailed check           72.10        3886.05
#
# [3 rows x 21 columns]

# %%
#ahora voy con las otras columnas tip object a booleano
#primero cambio los valores para poder pasarlos a booleano
cols_yes_no = ['Churn', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
datos[cols_yes_no] = datos[cols_yes_no].replace({'Yes': True, 'No': False})
datos.sample(5)
# Out:
# <ipython-input-205-72f7559a63ee>:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datos[cols_yes_no] = datos[cols_yes_no].replace({'Yes': True, 'No': False})
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 2560  3571-DPYUH  False    Male          False     True        True      58
# 3125  4359-INNWN  False  Female          False    False       False      17
# 4500  6169-PGNCD  False  Female          False    False       False      57
# 5417  7407-SUJIZ  False    Male          False    False       False      25
# 1184  1696-HXOWK  False  Female          False     True       False      71
#
#       PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 2560          True           Yes     Fiber optic  ...                  Yes
# 3125          True            No              No  ...  No internet service
# 4500          True            No             DSL  ...                  Yes
# 5417          True            No              No  ...  No internet service
# 1184          True           Yes     Fiber optic  ...                  Yes
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 2560                   No                  Yes                  Yes
# 3125  No internet service  No internet service  No internet service
# 4500                  Yes                  Yes                  Yes
# 5417  No internet service  No internet service  No internet service
# 1184                   No                   No                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 2560                   No        One year             True
# 3125  No internet service        One year            False
# 4500                   No        Two year             True
# 5417  No internet service  Month-to-month            False
# 1184                   No        One year            False
#
#                 PaymentMethod Charges.Monthly  Charges.Total
# 2560  Credit card (automatic)           94.70        5430.35
# 3125  Credit card (automatic)           20.05         337.90
# 4500  Credit card (automatic)           74.30        4166.35
# 5417             Mailed check           20.60         541.50
# 1184             Mailed check           95.65        6856.95
#
# [5 rows x 21 columns]

# %%
datos[cols_yes_no] = datos[cols_yes_no].astype(bool)

# %%
datos.sample(5)
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 5876  8035-BUYVG   True    Male          False     True       False      40
# 2500  3489-HHPFY  False  Female          False     True       False       2
# 4162  5701-YVSVF  False  Female           True     True       False      11
# 2383  3324-OIRTO  False    Male          False     True        True      71
# 1866  2656-FMOKZ   True  Female           True    False       False      15
#
#       PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 5876         False  No phone service             DSL  ...          Yes
# 2500          True               Yes     Fiber optic  ...           No
# 4162          True                No     Fiber optic  ...           No
# 2383          True                No     Fiber optic  ...          Yes
# 1866          True               Yes     Fiber optic  ...           No
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5876              Yes          No          No              No        One year
# 2500               No          No         Yes              No  Month-to-month
# 4162               No         Yes         Yes              No  Month-to-month
# 2383              Yes          No         Yes             Yes        One year
# 1866               No          No          No              No  Month-to-month
#
#      PaperlessBilling              PaymentMethod Charges.Monthly  \
# 5876             True           Electronic check           42.35
# 2500             True           Electronic check           84.05
# 4162             True           Electronic check           82.90
# 2383             True  Bank transfer (automatic)          104.65
# 1866             True               Mailed check           74.45
#
#       Charges.Total
# 5876        1716.45
# 2500         134.05
# 4162         880.05
# 2383        7288.40
# 1866        1145.70
#
# [5 rows x 21 columns]

# %%
#Ahra reviso las otras columnas que ddeben ser booleanas

# %%
datos[['PhoneService', 'MultipleLines', 'InternetService']].sample(10)
# Out:
#       PhoneService MultipleLines InternetService
# 6352          True           Yes              No
# 2415          True            No              No
# 3632          True            No             DSL
# 5367          True            No     Fiber optic
# 6018          True           Yes             DSL
# 722           True           Yes     Fiber optic
# 6387          True           Yes     Fiber optic
# 1636          True            No     Fiber optic
# 2240          True           Yes     Fiber optic
# 6938          True           Yes     Fiber optic

# %%
#quiero revisar mejor este valor para saber si se debe cambiar o no
datos[datos.isin(['No phone service']).any(axis=1)]
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 10    0017-DINOC  False    Male          False    False       False      54
# 14    0019-GFNTW  False  Female          False    False       False      56
# 16    0020-JDNXP  False  Female          False     True        True      34
# 19    0023-HGHWL   True    Male           True    False       False       1
# 25    0032-PGELS   True  Female          False     True        True       1
# ...          ...    ...     ...            ...      ...         ...     ...
# 7200  9906-NHHVC  False  Female           True    False       False      65
# 7201  9907-SWKKF   True  Female           True    False       False       1
# 7218  9928-BZVLZ  False  Female          False    False       False      12
# 7238  9955-QOPOY  False    Male          False     True       False      69
# 7266  9995-HOTOH  False    Male          False     True        True      63
#
#       PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# 10           False  No phone service             DSL  ...           No
# 14           False  No phone service             DSL  ...          Yes
# 16           False  No phone service             DSL  ...           No
# 19           False  No phone service             DSL  ...           No
# 25           False  No phone service             DSL  ...           No
# ...            ...               ...             ...  ...          ...
# 7200         False  No phone service             DSL  ...          Yes
# 7201         False  No phone service             DSL  ...           No
# 7218         False  No phone service             DSL  ...           No
# 7238         False  No phone service             DSL  ...          Yes
# 7266         False  No phone service             DSL  ...          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 10                 No         Yes         Yes              No        Two year
# 14                Yes         Yes          No              No        Two year
# 16                Yes         Yes         Yes             Yes        One year
# 19                 No          No          No              No  Month-to-month
# 25                 No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7200              Yes          No         Yes             Yes        Two year
# 7201               No          No          No              No  Month-to-month
# 7218              Yes         Yes          No             Yes        Two year
# 7238              Yes         Yes         Yes             Yes        One year
# 7266              Yes          No         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod Charges.Monthly  \
# 10              False    Credit card (automatic)           45.20
# 14              False  Bank transfer (automatic)           45.05
# 16              False               Mailed check           61.25
# 19               True           Electronic check           25.10
# 25              False  Bank transfer (automatic)           30.50
# ...               ...                        ...             ...
# 7200             True  Bank transfer (automatic)           53.50
# 7201            False               Mailed check           25.05
# 7218            False               Mailed check           49.85
# 7238             True    Credit card (automatic)           60.80
# 7266            False           Electronic check           59.00
#
#       Charges.Total
# 10          2460.55
# 14          2560.10
# 16          1993.20
# 19            25.10
# 25            30.50
# ...             ...
# 7200        3517.90
# 7201          25.05
# 7218         552.10
# 7238        4263.40
# 7266        3707.60
#
# [707 rows x 21 columns]

# %%
(datos == 'No phone service').sum()
# Out:
# customerID            0
# Churn                 0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# tenure                0
# PhoneService          0
# MultipleLines       707
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# Contract              0
# PaperlessBilling      0
# PaymentMethod         0
# Charges.Monthly       0
# Charges.Total         0
# dtype: int64

# %%
#Noto que "No phone service" siempre True, cuando no Phone Service es False.
#Es decir que se puede pasar a booleano

# %%
#Paso a revisar las otras columnas
datos['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
datos[datos.isin(['No internet service']).any(axis=1)]
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 20    0023-UYUPN  False  Female           True     True       False      50
# 23    0030-FNXPP  False  Female          False    False       False       3
# 24    0031-PVLZI   True  Female          False     True        True       4
# 27    0040-HALCW  False    Male          False     True        True      54
# 28    0042-JVWOJ  False    Male          False    False       False      26
# ...          ...    ...     ...            ...      ...         ...     ...
# 7250  9970-QBCDA  False  Female          False    False       False       6
# 7252  9972-EWRJS  False  Female          False     True        True      67
# 7256  9975-GPKZU  False    Male          False     True        True      46
# 7257  9975-SKRNR  False    Male          False    False       False       1
# 7261  9986-BONCE   True  Female          False    False       False       4
#
#       PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 20            True           Yes              No  ...  No internet service
# 23            True            No              No  ...  No internet service
# 24            True            No              No  ...  No internet service
# 27            True            No              No  ...  No internet service
# 28            True            No              No  ...  No internet service
# ...            ...           ...             ...  ...                  ...
# 7250          True            No              No  ...  No internet service
# 7252          True            No              No  ...  No internet service
# 7256          True            No              No  ...  No internet service
# 7257          True            No              No  ...  No internet service
# 7261          True            No              No  ...  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 20    No internet service  No internet service  No internet service
# 23    No internet service  No internet service  No internet service
# 24    No internet service  No internet service  No internet service
# 27    No internet service  No internet service  No internet service
# 28    No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7250  No internet service  No internet service  No internet service
# 7252  No internet service  No internet service  No internet service
# 7256  No internet service  No internet service  No internet service
# 7257  No internet service  No internet service  No internet service
# 7261  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 20    No internet service        One year            False
# 23    No internet service  Month-to-month            False
# 24    No internet service  Month-to-month            False
# 27    No internet service        Two year            False
# 28    No internet service        One year             True
# ...                   ...             ...              ...
# 7250  No internet service  Month-to-month            False
# 7252  No internet service        Two year             True
# 7256  No internet service        Two year            False
# 7257  No internet service  Month-to-month            False
# 7261  No internet service  Month-to-month            False
#
#                   PaymentMethod Charges.Monthly  Charges.Total
# 20             Electronic check           25.20        1306.30
# 23                 Mailed check           19.85          57.20
# 24                 Mailed check           20.35          76.35
# 27      Credit card (automatic)           20.40        1090.60
# 28    Bank transfer (automatic)           19.60         471.85
# ...                         ...             ...            ...
# 7250    Credit card (automatic)           19.70         129.55
# 7252  Bank transfer (automatic)           19.25        1372.90
# 7256    Credit card (automatic)           19.75         856.50
# 7257               Mailed check           18.90          18.90
# 7261  Bank transfer (automatic)           20.95          85.50
#
# [1581 rows x 21 columns]

# %%
(datos == 'No internet service').sum()
# Out:
# customerID             0
# Churn                  0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# tenure                 0
# PhoneService           0
# MultipleLines          0
# InternetService        0
# OnlineSecurity      1581
# OnlineBackup        1581
# DeviceProtection    1581
# TechSupport         1581
# StreamingTV         1581
# StreamingMovies     1581
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# Charges.Monthly        0
# Charges.Total          0
# dtype: int64

# %%
datos[datos['InternetService'] == 'No']
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 20    0023-UYUPN  False  Female           True     True       False      50
# 23    0030-FNXPP  False  Female          False    False       False       3
# 24    0031-PVLZI   True  Female          False     True        True       4
# 27    0040-HALCW  False    Male          False     True        True      54
# 28    0042-JVWOJ  False    Male          False    False       False      26
# ...          ...    ...     ...            ...      ...         ...     ...
# 7250  9970-QBCDA  False  Female          False    False       False       6
# 7252  9972-EWRJS  False  Female          False     True        True      67
# 7256  9975-GPKZU  False    Male          False     True        True      46
# 7257  9975-SKRNR  False    Male          False    False       False       1
# 7261  9986-BONCE   True  Female          False    False       False       4
#
#       PhoneService MultipleLines InternetService  ...         OnlineBackup  \
# 20            True           Yes              No  ...  No internet service
# 23            True            No              No  ...  No internet service
# 24            True            No              No  ...  No internet service
# 27            True            No              No  ...  No internet service
# 28            True            No              No  ...  No internet service
# ...            ...           ...             ...  ...                  ...
# 7250          True            No              No  ...  No internet service
# 7252          True            No              No  ...  No internet service
# 7256          True            No              No  ...  No internet service
# 7257          True            No              No  ...  No internet service
# 7261          True            No              No  ...  No internet service
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 20    No internet service  No internet service  No internet service
# 23    No internet service  No internet service  No internet service
# 24    No internet service  No internet service  No internet service
# 27    No internet service  No internet service  No internet service
# 28    No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 7250  No internet service  No internet service  No internet service
# 7252  No internet service  No internet service  No internet service
# 7256  No internet service  No internet service  No internet service
# 7257  No internet service  No internet service  No internet service
# 7261  No internet service  No internet service  No internet service
#
#           StreamingMovies        Contract PaperlessBilling  \
# 20    No internet service        One year            False
# 23    No internet service  Month-to-month            False
# 24    No internet service  Month-to-month            False
# 27    No internet service        Two year            False
# 28    No internet service        One year             True
# ...                   ...             ...              ...
# 7250  No internet service  Month-to-month            False
# 7252  No internet service        Two year             True
# 7256  No internet service        Two year            False
# 7257  No internet service  Month-to-month            False
# 7261  No internet service  Month-to-month            False
#
#                   PaymentMethod Charges.Monthly  Charges.Total
# 20             Electronic check           25.20        1306.30
# 23                 Mailed check           19.85          57.20
# 24                 Mailed check           20.35          76.35
# 27      Credit card (automatic)           20.40        1090.60
# 28    Bank transfer (automatic)           19.60         471.85
# ...                         ...             ...            ...
# 7250    Credit card (automatic)           19.70         129.55
# 7252  Bank transfer (automatic)           19.25        1372.90
# 7256    Credit card (automatic)           19.75         856.50
# 7257               Mailed check           18.90          18.90
# 7261  Bank transfer (automatic)           20.95          85.50
#
# [1581 rows x 21 columns]

# %%
# Noté que "No internet service" siempre es True en las columnas
# 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
# 'StreamingTV', 'StreamingMovies', cuando Internet Service es False(No)

# %%
cols_yes_no2 = ['MultipleLines','OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']

# %%
#hago una última comprobación de los datos.
for col in cols_yes_no2:
    print(f"{col}: {datos[col].unique()}")
# Out:
# MultipleLines: ['No' 'Yes' 'No phone service']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['Yes' 'No' 'No internet service']
# StreamingTV: ['Yes' 'No' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']

# %%
#Ahora, reemplazo los valores y cambio el tipo a booleano
mapeo = {
    'Yes': True,
    'No': False,
    'No phone service': False,
    'No internet service': False
}

for col in cols_yes_no2:
    datos[col] = datos[col].map(mapeo).astype(bool)

# %%
datos[cols_yes_no2].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MultipleLines     7267 non-null   bool
#  1   OnlineSecurity    7267 non-null   bool
#  2   OnlineBackup      7267 non-null   bool
#  3   DeviceProtection  7267 non-null   bool
#  4   TechSupport       7267 non-null   bool
#  5   StreamingTV       7267 non-null   bool
#  6   StreamingMovies   7267 non-null   bool
# dtypes: bool(7)
# memory usage: 49.8 KB

# %%
datos.sample(5)
# Out:
#       customerID  Churn  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 1380  1996-DBMUS  False  Female           True     True       False      48
# 6019  8219-VYBVI  False    Male          False    False        True      39
# 5160  7037-MTYVW  False    Male          False     True        True      38
# 1430  2056-EVGZL  False    Male          False     True        True      68
# 5037  6892-BOGQE  False  Female          False     True       False      71
#
#       PhoneService  MultipleLines InternetService  ...  OnlineBackup  \
# 1380          True          False     Fiber optic  ...         False
# 6019          True           True              No  ...         False
# 5160          True           True             DSL  ...         False
# 1430          True          False     Fiber optic  ...          True
# 5037          True          False              No  ...         False
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 1380             False        False        False            False
# 6019             False        False        False            False
# 5160              True         True         True             True
# 1430              True         True         True             True
# 5037             False        False        False            False
#
#             Contract PaperlessBilling              PaymentMethod  \
# 1380  Month-to-month             True  Bank transfer (automatic)
# 6019        Two year            False               Mailed check
# 5160        Two year             True  Bank transfer (automatic)
# 1430        One year            False    Credit card (automatic)
# 5037        Two year             True  Bank transfer (automatic)
#
#      Charges.Monthly  Charges.Total
# 1380           70.65        3545.05
# 6019           25.00        1004.35
# 5160           85.40        3297.00
# 1430          105.75        7322.50
# 5037           20.90        1493.20
#
# [5 rows x 21 columns]

# %% [markdown]
# #Carga y Análisis

# %% [markdown]
# #Informe Final
